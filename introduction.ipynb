# %% [markdown]
# **“A Simple Parameter Inference with Transformers” - Introduction**

# %%
from main import *

# %% [markdown]
# <span style="font-size: 30px;">First model</span>
#
# - first regression model only
# $$y(t) = \sin(\omega \cdot t)$$

# %%
main1(plot1=True)
# Out:
# Test MSE 0.006342, MAE 0.063750

# %% [markdown]
# <span style="font-size: 30px;">Second model</span>
#
# - probabilistic model only with prediction with one frequency parameter $$y(t) = \sin(\omega \cdot t)$$

# %%
main2()
# Out:
# Test MSE 0.001052, MAE 0.025040

# %% [markdown]
# <span style="font-size: 30px;">Third final model</span>
#
# - probabilistic model only with prediction with two frequency parameters
# - linear mixture
# $$y(t) = \sin(\omega_1 \cdot t) + \sin(\omega_2 \cdot t)$$

# %%
main3(dataset="linear")
# Out:
# Test MSE 0.015823, MAE 0.097533

# %% [markdown]
# - nonlinear mixture $$y(t) = \sin(\omega_1 \cdot t) + \sin(\omega_2 \cdot t) + \sin(\omega_1 \cdot t) \cdot \sin(\omega_2 \cdot t)$$

# %%
main3(dataset="nonlinear")
# Out:
# Test MSE 0.013789, MAE 0.087584
